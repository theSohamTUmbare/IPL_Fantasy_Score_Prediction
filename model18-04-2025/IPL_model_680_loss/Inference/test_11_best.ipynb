# %%
# Out:
# Processing match: 1473438
# Player feature map written to C:\Users\kumar\IPL_Fantasy_Score_Prediction\tests\ipl_2025_MatchData\1473438.csv
# Processing match: 1473439
# Player feature map written to C:\Users\kumar\IPL_Fantasy_Score_Prediction\tests\ipl_2025_MatchData\1473439.csv
# Processing match: 1473440
# Player feature map written to C:\Users\kumar\IPL_Fantasy_Score_Prediction\tests\ipl_2025_MatchData\1473440.csv
# Processing match: 1473441
# Player feature map written to C:\Users\kumar\IPL_Fantasy_Score_Prediction\tests\ipl_2025_MatchData\1473441.csv
# Processing match: 1473442
# Player feature map written to C:\Users\kumar\IPL_Fantasy_Score_Prediction\tests\ipl_2025_MatchData\1473442.csv
# Processing match: 1473443
# Player feature map written to C:\Users\kumar\IPL_Fantasy_Score_Prediction\tests\ipl_2025_MatchData\1473443.csv
# Processing match: 1473444
# Player feature map written to C:\Users\kumar\IPL_Fantasy_Score_Prediction\tests\ipl_2025_MatchData\1473444.csv

# %%
import numpy as np
import pandas as pd

# %%
match01_player = pd.read_csv('SquadPlayerNames_IndianT20League - Match_1.csv')
match01_player.sort_values(by=['Team','lineupOrder'],inplace=True)
match01_player = match01_player[match01_player['IsPlaying'] != 'NOT_PLAYING']
match01_player
# Out:
#     Credits Player Type           Player Name Team            IsPlaying  \
# 15      8.0          WK       Quinton de Kock  KKR              PLAYING
# 25      8.0         BAT        Venkatesh Iyer  KKR              PLAYING
# 27      7.5         BAT        Ajinkya Rahane  KKR              PLAYING
# 24      7.5         BAT           Rinku Singh  KKR              PLAYING
# 22      6.5         BAT  Angkrish Raghuvanshi  KKR              PLAYING
# 10      9.0         ALL          Sunil Narine  KKR              PLAYING
# 9       8.5         ALL         Andre Russell  KKR              PLAYING
# 7       7.5         ALL       Ramandeep Singh  KKR              PLAYING
# 40      6.5        BOWL       Spencer Johnson  KKR              PLAYING
# 36      8.0        BOWL          Harshit Rana  KKR              PLAYING
# 41      9.0        BOWL    Varun Chakravarthy  KKR              PLAYING
# 42      8.0        BOWL         Anrich Nortje  KKR  X_FACTOR_SUBSTITUTE
# 26      7.0         BAT         Manish Pandey  KKR  X_FACTOR_SUBSTITUTE
# 38      6.5        BOWL         Vaibhav Arora  KKR  X_FACTOR_SUBSTITUTE
# 6       6.0         ALL   Anukul Sudhakar Roy  KKR  X_FACTOR_SUBSTITUTE
# 13      5.5          WK       Luvnith Sisodia  KKR  X_FACTOR_SUBSTITUTE
# 21      9.0         BAT           Virat Kohli  RCB              PLAYING
# 12      8.5          WK           Philip Salt  RCB              PLAYING
# 20      8.0         BAT         Rajat Patidar  RCB              PLAYING
# 4       8.0         ALL      Liam Livingstone  RCB              PLAYING
# 11      7.5          WK         Jitesh Sharma  RCB              PLAYING
# 18      7.5         BAT             Tim David  RCB              PLAYING
# 3       7.5         ALL         Krunal Pandya  RCB              PLAYING
# 30      6.5        BOWL          Rasikh Salam  RCB              PLAYING
# 29      6.0        BOWL         Suyash Sharma  RCB              PLAYING
# 34      8.5        BOWL        Josh Hazlewood  RCB              PLAYING
# 31      7.0        BOWL            Yash Dayal  RCB              PLAYING
# 19      7.0         BAT      Devdutt Padikkal  RCB  X_FACTOR_SUBSTITUTE
# 28      5.0        BOWL      Abhinandan Singh  RCB  X_FACTOR_SUBSTITUTE
# 1       6.5         ALL        Manoj Bhandage  RCB  X_FACTOR_SUBSTITUTE
# 2       7.0         ALL      Romario Shepherd  RCB  X_FACTOR_SUBSTITUTE
# 5       7.0         ALL         Swapnil Singh  RCB  X_FACTOR_SUBSTITUTE
#
#     lineupOrder
# 15            1
# 25            2
# 27            3
# 24            4
# 22            5
# 10            6
# 9             7
# 7             8
# 40            9
# 36           10
# 41           11
# 42           12
# 26           13
# 38           14
# 6            15
# 13           16
# 21            1
# 12            2
# 20            3
# 4             4
# 11            5
# 18            6
# 3             7
# 30            8
# 29            9
# 34           10
# 31           11
# 19           12
# 28           13
# 1            14
# 2            15
# 5            16

# %%
team_map = {
    'KKR': 'Kolkata Knight Riders',
    'RCB': 'Royal Challengers Bengaluru'
}

# Define a mapping from the player names in match01_player to the corresponding names in df_stats.
player_map = {
    'Quinton de Kock': 'Q de Kock',#
    'Venkatesh Iyer': 'VR Iyer',#
    'Ajinkya Rahane': 'AM Rahane',#
    'Angkrish Raghuvanshi': 'A Raghuvanshi',#
    'Sunil Narine': 'SP Narine',#
    'Rinku Singh' :'RK Singh',#
    'Andre Russell': 'AD Russell',#
    'Ramandeep Singh': 'Ramandeep Singh',#  # same in both dataframes
    'Spencer Johnson': 'SH Johnson',#
    'Harshit Rana': 'Harshit Rana',#
    'Varun Chakravarthy': 'CV Varun',#
    'Vaibhav Arora': 'VG Arora',#
    # RCB mappings
    'Virat Kohli': 'V Kohli',#
    'Philip Salt': 'PD Salt',#
    'Devdutt Padikkal' : 'D Padikkal',#
    'Rajat Patidar' : 'RM Patidar',#
    'Suyash Sharma' : 'Suyash Sharma',
    'Liam Livingstone': 'LS Livingstone',
    'Jitesh Sharma': 'JM Sharma',
    'Tim David': 'TH David',
    'Krunal Pandya': 'KH Pandya',
    'Rasikh Salam': 'Rasikh Salam',
    'Josh Hazlewood' : 'JR Hazlewood',
    'Yash Dayal' : 'Yash Dayal'
}
match01_player['Team'] = match01_player['Team'].map(team_map)
match01_player['Player Name'] = match01_player['Player Name'].map(player_map)
match01_player = match01_player.dropna(axis=0)
match01_player
# Out:
#     Credits Player Type      Player Name                         Team  \
# 15      8.0          WK        Q de Kock        Kolkata Knight Riders
# 25      8.0         BAT          VR Iyer        Kolkata Knight Riders
# 27      7.5         BAT        AM Rahane        Kolkata Knight Riders
# 24      7.5         BAT         RK Singh        Kolkata Knight Riders
# 22      6.5         BAT    A Raghuvanshi        Kolkata Knight Riders
# 10      9.0         ALL        SP Narine        Kolkata Knight Riders
# 9       8.5         ALL       AD Russell        Kolkata Knight Riders
# 7       7.5         ALL  Ramandeep Singh        Kolkata Knight Riders
# 40      6.5        BOWL       SH Johnson        Kolkata Knight Riders
# 36      8.0        BOWL     Harshit Rana        Kolkata Knight Riders
# 41      9.0        BOWL         CV Varun        Kolkata Knight Riders
# 38      6.5        BOWL         VG Arora        Kolkata Knight Riders
# 21      9.0         BAT          V Kohli  Royal Challengers Bengaluru
# 12      8.5          WK          PD Salt  Royal Challengers Bengaluru
# 20      8.0         BAT       RM Patidar  Royal Challengers Bengaluru
# 4       8.0         ALL   LS Livingstone  Royal Challengers Bengaluru
# 11      7.5          WK        JM Sharma  Royal Challengers Bengaluru
# 18      7.5         BAT         TH David  Royal Challengers Bengaluru
# 3       7.5         ALL        KH Pandya  Royal Challengers Bengaluru
# 30      6.5        BOWL     Rasikh Salam  Royal Challengers Bengaluru
# 29      6.0        BOWL    Suyash Sharma  Royal Challengers Bengaluru
# 34      8.5        BOWL     JR Hazlewood  Royal Challengers Bengaluru
# 31      7.0        BOWL       Yash Dayal  Royal Challengers Bengaluru
# 19      7.0         BAT       D Padikkal  Royal Challengers Bengaluru
#
#               IsPlaying  lineupOrder
# 15              PLAYING            1
# 25              PLAYING            2
# 27              PLAYING            3
# 24              PLAYING            4
# 22              PLAYING            5
# 10              PLAYING            6
# 9               PLAYING            7
# 7               PLAYING            8
# 40              PLAYING            9
# 36              PLAYING           10
# 41              PLAYING           11
# 38  X_FACTOR_SUBSTITUTE           14
# 21              PLAYING            1
# 12              PLAYING            2
# 20              PLAYING            3
# 4               PLAYING            4
# 11              PLAYING            5
# 18              PLAYING            6
# 3               PLAYING            7
# 30              PLAYING            8
# 29              PLAYING            9
# 34              PLAYING           10
# 31              PLAYING           11
# 19  X_FACTOR_SUBSTITUTE           12

# %%
match01 = pd.read_csv(r"C:\Users\kumar\IPL_Fantasy_Score_Prediction\tests\ipl_2025_MatchData\1473438.csv")
match01
# Out:
#                            Team             name player_id  batting_position  \
# 0         Kolkata Knight Riders        Q de Kock  372455c4                 1
# 1         Kolkata Knight Riders        SP Narine  9d430b40                 2
# 2         Kolkata Knight Riders        AM Rahane  29e95537                 3
# 3         Kolkata Knight Riders          VR Iyer  a24be938                 4
# 4         Kolkata Knight Riders    A Raghuvanshi  d7017798                 5
# 5         Kolkata Knight Riders         VG Arora  7c3b3b78                 5
# 6         Kolkata Knight Riders         RK Singh  0a509d6b                 6
# 7         Kolkata Knight Riders         CV Varun  5b7ab5a9                 6
# 8         Kolkata Knight Riders       AD Russell  bbd41817                 7
# 9         Kolkata Knight Riders  Ramandeep Singh  be24ead0                 8
# 10        Kolkata Knight Riders     Harshit Rana  77b1aa15                 9
# 11        Kolkata Knight Riders       SH Johnson  83c3e8e3                10
# 12  Royal Challengers Bengaluru          PD Salt  3d284ca3                 1
# 13  Royal Challengers Bengaluru          V Kohli  ba607b88                 2
# 14  Royal Challengers Bengaluru       D Padikkal  2c25d4f5                 3
# 15  Royal Challengers Bengaluru       RM Patidar  c740ea83                 4
# 16  Royal Challengers Bengaluru    Suyash Sharma  9440ef41                 5
# 17  Royal Challengers Bengaluru   LS Livingstone  50c6bc2b                 5
# 18  Royal Challengers Bengaluru        JM Sharma  800d2d97                 6
# 19  Royal Challengers Bengaluru         TH David  f1f99156                 7
# 20  Royal Challengers Bengaluru        KH Pandya  5b8c830e                 8
# 21  Royal Challengers Bengaluru     Rasikh Salam  b8527c3d                 9
# 22  Royal Challengers Bengaluru     JR Hazlewood  03806cf8                10
# 23  Royal Challengers Bengaluru       Yash Dayal  7210d461                11
#
#     runs  balls  fours  sixes  strike_rate     overs_bowled  ...  \
# 0      4      5      1      0        80.00               []  ...
# 1     44     26      5      3       169.23  [8, 10, 12, 14]  ...
# 2     56     31      6      4       180.65               []  ...
# 3      6      7      1      0        85.71               []  ...
# 4     30     22      2      1       136.36               []  ...
# 5      0      0      0      0         0.00       [1, 3, 16]  ...
# 6     12     10      1      0       120.00               []  ...
# 7      0      0      0      0         0.00    [4, 7, 9, 11]  ...
# 8      4      3      1      0       133.33               []  ...
# 9      6      9      0      0        66.67               []  ...
# 10     5      6      1      0        83.33      [6, 13, 15]  ...
# 11     1      1      0      0       100.00       [2, 5, 17]  ...
# 12    56     31      9      2       180.65               []  ...
# 13    59     36      4      3       163.89               []  ...
# 14    10     10      1      0       100.00               []  ...
# 15    34     16      5      1       212.50               []  ...
# 16     0      0      0      0         0.00   [7, 9, 12, 16]  ...
# 17    15      5      2      1       300.00         [14, 17]  ...
# 18     0      0      0      0         0.00               []  ...
# 19     0      0      0      0         0.00               []  ...
# 20     0      0      0      0         0.00  [5, 11, 13, 15]  ...
# 21     0      0      0      0         0.00       [4, 8, 10]  ...
# 22     0      0      0      0         0.00   [1, 3, 18, 20]  ...
# 23     0      0      0      0         0.00       [2, 6, 19]  ...
#
#     economy_rate  catches  stumping  direct_hit  indirect_hit  strike_rate_fp  \
# 0           0.00        0         0           0             0               0
# 1           6.75        0         0           0             0               4
# 2           0.00        0         0           0             0               6
# 3           0.00        0         0           0             0               0
# 4           0.00        0         0           0             0               2
# 5          14.00        0         0           0             0               0
# 6           0.00        1         0           0             0               0
# 7          10.75        0         0           0             0               0
# 8           0.00        0         0           0             0               0
# 9           0.00        1         0           0             0               0
# 10         10.67        0         0           0             0               0
# 11         13.29        1         0           0             0               0
# 12          0.00        0         0           0             0               6
# 13          0.00        0         0           0             0               4
# 14          0.00        0         0           0             0               0
# 15          0.00        0         0           0             0               6
# 16         11.75        0         0           0             0               0
# 17          7.00        0         0           0             0               0
# 18          0.00        4         0           0             0               0
# 19          0.00        0         0           0             0               0
# 20          7.25        0         0           0             0               0
# 21         11.67        1         0           0             0               0
# 22          5.50        0         0           0             0               0
# 23          8.33        0         0           0             0               0
#
#     batting_fp  bowling_fp  fielding_fp  total_fp
# 0            8           0            0        12
# 1           90          31            0       125
# 2          118           0            0       122
# 3           10           0            0        14
# 4           50           0            0        54
# 5            0          23            0        27
# 6           16           0            8        28
# 7            0          30            0        34
# 8            8           0            0        12
# 9            6           0            8        18
# 10           9           2            0        15
# 11           1           0            8        13
# 12         118           0            0       122
# 13         105           0            0       109
# 14          14           0            0        18
# 15          70           0            0        74
# 16           0          37            0        41
# 17          29           4            0        37
# 18           0           0           36        40
# 19           0           0            0         4
# 20           0         103            0       107
# 21           0          29            8        41
# 22           0          69            0        73
# 23           0          32            0        36
#
# [24 rows x 32 columns]

# %%
# match01_player = match01_player.merge(match01[['name','total_fp']],left_on='Player Name',right_on='name',how='left')
# match01_player

# %%
match01_player = match01_player.join(
    match01.set_index('name')['total_fp'],
    on='Player Name'
)
match01_player.reset_index()
# Out:
#     index  Credits Player Type      Player Name                         Team  \
# 0      15      8.0          WK        Q de Kock        Kolkata Knight Riders
# 1      25      8.0         BAT          VR Iyer        Kolkata Knight Riders
# 2      27      7.5         BAT        AM Rahane        Kolkata Knight Riders
# 3      24      7.5         BAT         RK Singh        Kolkata Knight Riders
# 4      22      6.5         BAT    A Raghuvanshi        Kolkata Knight Riders
# 5      10      9.0         ALL        SP Narine        Kolkata Knight Riders
# 6       9      8.5         ALL       AD Russell        Kolkata Knight Riders
# 7       7      7.5         ALL  Ramandeep Singh        Kolkata Knight Riders
# 8      40      6.5        BOWL       SH Johnson        Kolkata Knight Riders
# 9      36      8.0        BOWL     Harshit Rana        Kolkata Knight Riders
# 10     41      9.0        BOWL         CV Varun        Kolkata Knight Riders
# 11     38      6.5        BOWL         VG Arora        Kolkata Knight Riders
# 12     21      9.0         BAT          V Kohli  Royal Challengers Bengaluru
# 13     12      8.5          WK          PD Salt  Royal Challengers Bengaluru
# 14     20      8.0         BAT       RM Patidar  Royal Challengers Bengaluru
# 15      4      8.0         ALL   LS Livingstone  Royal Challengers Bengaluru
# 16     11      7.5          WK        JM Sharma  Royal Challengers Bengaluru
# 17     18      7.5         BAT         TH David  Royal Challengers Bengaluru
# 18      3      7.5         ALL        KH Pandya  Royal Challengers Bengaluru
# 19     30      6.5        BOWL     Rasikh Salam  Royal Challengers Bengaluru
# 20     29      6.0        BOWL    Suyash Sharma  Royal Challengers Bengaluru
# 21     34      8.5        BOWL     JR Hazlewood  Royal Challengers Bengaluru
# 22     31      7.0        BOWL       Yash Dayal  Royal Challengers Bengaluru
# 23     19      7.0         BAT       D Padikkal  Royal Challengers Bengaluru
#
#               IsPlaying  lineupOrder  total_fp
# 0               PLAYING            1        12
# 1               PLAYING            2        14
# 2               PLAYING            3       122
# 3               PLAYING            4        28
# 4               PLAYING            5        54
# 5               PLAYING            6       125
# 6               PLAYING            7        12
# 7               PLAYING            8        18
# 8               PLAYING            9        13
# 9               PLAYING           10        15
# 10              PLAYING           11        34
# 11  X_FACTOR_SUBSTITUTE           14        27
# 12              PLAYING            1       109
# 13              PLAYING            2       122
# 14              PLAYING            3        74
# 15              PLAYING            4        37
# 16              PLAYING            5        40
# 17              PLAYING            6         4
# 18              PLAYING            7       107
# 19              PLAYING            8        41
# 20              PLAYING            9        41
# 21              PLAYING           10        73
# 22              PLAYING           11        36
# 23  X_FACTOR_SUBSTITUTE           12        18

# %%
match01_player.reset_index(inplace=True)
match01_player
# Out:
#     index  Credits Player Type      Player Name                         Team  \
# 0      15      8.0          WK        Q de Kock        Kolkata Knight Riders
# 1      25      8.0         BAT          VR Iyer        Kolkata Knight Riders
# 2      27      7.5         BAT        AM Rahane        Kolkata Knight Riders
# 3      24      7.5         BAT         RK Singh        Kolkata Knight Riders
# 4      22      6.5         BAT    A Raghuvanshi        Kolkata Knight Riders
# 5      10      9.0         ALL        SP Narine        Kolkata Knight Riders
# 6       9      8.5         ALL       AD Russell        Kolkata Knight Riders
# 7       7      7.5         ALL  Ramandeep Singh        Kolkata Knight Riders
# 8      40      6.5        BOWL       SH Johnson        Kolkata Knight Riders
# 9      36      8.0        BOWL     Harshit Rana        Kolkata Knight Riders
# 10     41      9.0        BOWL         CV Varun        Kolkata Knight Riders
# 11     38      6.5        BOWL         VG Arora        Kolkata Knight Riders
# 12     21      9.0         BAT          V Kohli  Royal Challengers Bengaluru
# 13     12      8.5          WK          PD Salt  Royal Challengers Bengaluru
# 14     20      8.0         BAT       RM Patidar  Royal Challengers Bengaluru
# 15      4      8.0         ALL   LS Livingstone  Royal Challengers Bengaluru
# 16     11      7.5          WK        JM Sharma  Royal Challengers Bengaluru
# 17     18      7.5         BAT         TH David  Royal Challengers Bengaluru
# 18      3      7.5         ALL        KH Pandya  Royal Challengers Bengaluru
# 19     30      6.5        BOWL     Rasikh Salam  Royal Challengers Bengaluru
# 20     29      6.0        BOWL    Suyash Sharma  Royal Challengers Bengaluru
# 21     34      8.5        BOWL     JR Hazlewood  Royal Challengers Bengaluru
# 22     31      7.0        BOWL       Yash Dayal  Royal Challengers Bengaluru
# 23     19      7.0         BAT       D Padikkal  Royal Challengers Bengaluru
#
#               IsPlaying  lineupOrder  total_fp
# 0               PLAYING            1        12
# 1               PLAYING            2        14
# 2               PLAYING            3       122
# 3               PLAYING            4        28
# 4               PLAYING            5        54
# 5               PLAYING            6       125
# 6               PLAYING            7        12
# 7               PLAYING            8        18
# 8               PLAYING            9        13
# 9               PLAYING           10        15
# 10              PLAYING           11        34
# 11  X_FACTOR_SUBSTITUTE           14        27
# 12              PLAYING            1       109
# 13              PLAYING            2       122
# 14              PLAYING            3        74
# 15              PLAYING            4        37
# 16              PLAYING            5        40
# 17              PLAYING            6         4
# 18              PLAYING            7       107
# 19              PLAYING            8        41
# 20              PLAYING            9        41
# 21              PLAYING           10        73
# 22              PLAYING           11        36
# 23  X_FACTOR_SUBSTITUTE           12        18

# %% [markdown]
# 1-04-25

# %%
import pandas as pd 
import pulp 

df = pd.read_csv('SquadPlayerNames_IndianT20League - Match_1.csv')
df = df[df['IsPlaying'] != 'NOT_PLAYING']
df.sort_values(['Team','lineupOrder'],inplace=True)
df
# Out:
#     Credits Player Type           Player Name Team            IsPlaying  \
# 15      8.0          WK       Quinton de Kock  KKR              PLAYING
# 25      8.0         BAT        Venkatesh Iyer  KKR              PLAYING
# 27      7.5         BAT        Ajinkya Rahane  KKR              PLAYING
# 24      7.5         BAT           Rinku Singh  KKR              PLAYING
# 22      6.5         BAT  Angkrish Raghuvanshi  KKR              PLAYING
# 10      9.0         ALL          Sunil Narine  KKR              PLAYING
# 9       8.5         ALL         Andre Russell  KKR              PLAYING
# 7       7.5         ALL       Ramandeep Singh  KKR              PLAYING
# 40      6.5        BOWL       Spencer Johnson  KKR              PLAYING
# 36      8.0        BOWL          Harshit Rana  KKR              PLAYING
# 41      9.0        BOWL    Varun Chakravarthy  KKR              PLAYING
# 42      8.0        BOWL         Anrich Nortje  KKR  X_FACTOR_SUBSTITUTE
# 26      7.0         BAT         Manish Pandey  KKR  X_FACTOR_SUBSTITUTE
# 38      6.5        BOWL         Vaibhav Arora  KKR  X_FACTOR_SUBSTITUTE
# 6       6.0         ALL   Anukul Sudhakar Roy  KKR  X_FACTOR_SUBSTITUTE
# 13      5.5          WK       Luvnith Sisodia  KKR  X_FACTOR_SUBSTITUTE
# 21      9.0         BAT           Virat Kohli  RCB              PLAYING
# 12      8.5          WK           Philip Salt  RCB              PLAYING
# 20      8.0         BAT         Rajat Patidar  RCB              PLAYING
# 4       8.0         ALL      Liam Livingstone  RCB              PLAYING
# 11      7.5          WK         Jitesh Sharma  RCB              PLAYING
# 18      7.5         BAT             Tim David  RCB              PLAYING
# 3       7.5         ALL         Krunal Pandya  RCB              PLAYING
# 30      6.5        BOWL          Rasikh Salam  RCB              PLAYING
# 29      6.0        BOWL         Suyash Sharma  RCB              PLAYING
# 34      8.5        BOWL        Josh Hazlewood  RCB              PLAYING
# 31      7.0        BOWL            Yash Dayal  RCB              PLAYING
# 19      7.0         BAT      Devdutt Padikkal  RCB  X_FACTOR_SUBSTITUTE
# 28      5.0        BOWL      Abhinandan Singh  RCB  X_FACTOR_SUBSTITUTE
# 1       6.5         ALL        Manoj Bhandage  RCB  X_FACTOR_SUBSTITUTE
# 2       7.0         ALL      Romario Shepherd  RCB  X_FACTOR_SUBSTITUTE
# 5       7.0         ALL         Swapnil Singh  RCB  X_FACTOR_SUBSTITUTE
#
#     lineupOrder
# 15            1
# 25            2
# 27            3
# 24            4
# 22            5
# 10            6
# 9             7
# 7             8
# 40            9
# 36           10
# 41           11
# 42           12
# 26           13
# 38           14
# 6            15
# 13           16
# 21            1
# 12            2
# 20            3
# 4             4
# 11            5
# 18            6
# 3             7
# 30            8
# 29            9
# 34           10
# 31           11
# 19           12
# 28           13
# 1            14
# 2            15
# 5            16

# %%
team_map = {
    'KKR': 'Kolkata Knight Riders',
    'RCB': 'Royal Challengers Bengaluru'
}

# Define a mapping from the player names in match01_player to the corresponding names in df_stats.
player_map = {
    'Quinton de Kock': 'Q de Kock',#
    'Venkatesh Iyer': 'VR Iyer',#
    'Ajinkya Rahane': 'AM Rahane',#
    'Angkrish Raghuvanshi': 'A Raghuvanshi',#
    'Sunil Narine': 'SP Narine',#
    'Rinku Singh' :'RK Singh',#
    'Andre Russell': 'AD Russell',#
    'Ramandeep Singh': 'Ramandeep Singh',#  # same in both dataframes
    'Spencer Johnson': 'SH Johnson',#
    'Harshit Rana': 'Harshit Rana',#
    'Varun Chakravarthy': 'CV Varun',#
    'Vaibhav Arora': 'VG Arora',#
    # RCB mappings
    'Virat Kohli': 'V Kohli',#
    'Philip Salt': 'PD Salt',#
    'Devdutt Padikkal' : 'D Padikkal',#
    'Rajat Patidar' : 'RM Patidar',#
    'Suyash Sharma' : 'Suyash Sharma',
    'Liam Livingstone': 'LS Livingstone',
    'Jitesh Sharma': 'JM Sharma',
    'Tim David': 'TH David',
    'Krunal Pandya': 'KH Pandya',
    'Rasikh Salam': 'Rasikh Salam',
    'Josh Hazlewood' : 'JR Hazlewood',
    'Yash Dayal' : 'Yash Dayal'
}
df['Team'] = df['Team'].map(team_map)
df['Player Name'] = df['Player Name'].map(player_map)
df
# Out:
#     Credits Player Type      Player Name                         Team  \
# 15      8.0          WK        Q de Kock        Kolkata Knight Riders
# 25      8.0         BAT          VR Iyer        Kolkata Knight Riders
# 27      7.5         BAT        AM Rahane        Kolkata Knight Riders
# 24      7.5         BAT         RK Singh        Kolkata Knight Riders
# 22      6.5         BAT    A Raghuvanshi        Kolkata Knight Riders
# 10      9.0         ALL        SP Narine        Kolkata Knight Riders
# 9       8.5         ALL       AD Russell        Kolkata Knight Riders
# 7       7.5         ALL  Ramandeep Singh        Kolkata Knight Riders
# 40      6.5        BOWL       SH Johnson        Kolkata Knight Riders
# 36      8.0        BOWL     Harshit Rana        Kolkata Knight Riders
# 41      9.0        BOWL         CV Varun        Kolkata Knight Riders
# 42      8.0        BOWL              NaN        Kolkata Knight Riders
# 26      7.0         BAT              NaN        Kolkata Knight Riders
# 38      6.5        BOWL         VG Arora        Kolkata Knight Riders
# 6       6.0         ALL              NaN        Kolkata Knight Riders
# 13      5.5          WK              NaN        Kolkata Knight Riders
# 21      9.0         BAT          V Kohli  Royal Challengers Bengaluru
# 12      8.5          WK          PD Salt  Royal Challengers Bengaluru
# 20      8.0         BAT       RM Patidar  Royal Challengers Bengaluru
# 4       8.0         ALL   LS Livingstone  Royal Challengers Bengaluru
# 11      7.5          WK        JM Sharma  Royal Challengers Bengaluru
# 18      7.5         BAT         TH David  Royal Challengers Bengaluru
# 3       7.5         ALL        KH Pandya  Royal Challengers Bengaluru
# 30      6.5        BOWL     Rasikh Salam  Royal Challengers Bengaluru
# 29      6.0        BOWL    Suyash Sharma  Royal Challengers Bengaluru
# 34      8.5        BOWL     JR Hazlewood  Royal Challengers Bengaluru
# 31      7.0        BOWL       Yash Dayal  Royal Challengers Bengaluru
# 19      7.0         BAT       D Padikkal  Royal Challengers Bengaluru
# 28      5.0        BOWL              NaN  Royal Challengers Bengaluru
# 1       6.5         ALL              NaN  Royal Challengers Bengaluru
# 2       7.0         ALL              NaN  Royal Challengers Bengaluru
# 5       7.0         ALL              NaN  Royal Challengers Bengaluru
#
#               IsPlaying  lineupOrder
# 15              PLAYING            1
# 25              PLAYING            2
# 27              PLAYING            3
# 24              PLAYING            4
# 22              PLAYING            5
# 10              PLAYING            6
# 9               PLAYING            7
# 7               PLAYING            8
# 40              PLAYING            9
# 36              PLAYING           10
# 41              PLAYING           11
# 42  X_FACTOR_SUBSTITUTE           12
# 26  X_FACTOR_SUBSTITUTE           13
# 38  X_FACTOR_SUBSTITUTE           14
# 6   X_FACTOR_SUBSTITUTE           15
# 13  X_FACTOR_SUBSTITUTE           16
# 21              PLAYING            1
# 12              PLAYING            2
# 20              PLAYING            3
# 4               PLAYING            4
# 11              PLAYING            5
# 18              PLAYING            6
# 3               PLAYING            7
# 30              PLAYING            8
# 29              PLAYING            9
# 34              PLAYING           10
# 31              PLAYING           11
# 19  X_FACTOR_SUBSTITUTE           12
# 28  X_FACTOR_SUBSTITUTE           13
# 1   X_FACTOR_SUBSTITUTE           14
# 2   X_FACTOR_SUBSTITUTE           15
# 5   X_FACTOR_SUBSTITUTE           16

# %%
match_1 = pd.read_csv(r'ipl_2025_MatchData\1473438.csv')
match_1
# Out:
#                            Team             name player_id  batting_position  \
# 0         Kolkata Knight Riders        Q de Kock  372455c4                 1
# 1         Kolkata Knight Riders        SP Narine  9d430b40                 2
# 2         Kolkata Knight Riders        AM Rahane  29e95537                 3
# 3         Kolkata Knight Riders          VR Iyer  a24be938                 4
# 4         Kolkata Knight Riders    A Raghuvanshi  d7017798                 5
# 5         Kolkata Knight Riders         VG Arora  7c3b3b78                 5
# 6         Kolkata Knight Riders         RK Singh  0a509d6b                 6
# 7         Kolkata Knight Riders         CV Varun  5b7ab5a9                 6
# 8         Kolkata Knight Riders       AD Russell  bbd41817                 7
# 9         Kolkata Knight Riders  Ramandeep Singh  be24ead0                 8
# 10        Kolkata Knight Riders     Harshit Rana  77b1aa15                 9
# 11        Kolkata Knight Riders       SH Johnson  83c3e8e3                10
# 12  Royal Challengers Bengaluru          PD Salt  3d284ca3                 1
# 13  Royal Challengers Bengaluru          V Kohli  ba607b88                 2
# 14  Royal Challengers Bengaluru       D Padikkal  2c25d4f5                 3
# 15  Royal Challengers Bengaluru       RM Patidar  c740ea83                 4
# 16  Royal Challengers Bengaluru    Suyash Sharma  9440ef41                 5
# 17  Royal Challengers Bengaluru   LS Livingstone  50c6bc2b                 5
# 18  Royal Challengers Bengaluru        JM Sharma  800d2d97                 6
# 19  Royal Challengers Bengaluru         TH David  f1f99156                 7
# 20  Royal Challengers Bengaluru        KH Pandya  5b8c830e                 8
# 21  Royal Challengers Bengaluru     Rasikh Salam  b8527c3d                 9
# 22  Royal Challengers Bengaluru     JR Hazlewood  03806cf8                10
# 23  Royal Challengers Bengaluru       Yash Dayal  7210d461                11
#
#     runs  balls  fours  sixes  strike_rate     overs_bowled  ...  \
# 0      4      5      1      0        80.00               []  ...
# 1     44     26      5      3       169.23  [8, 10, 12, 14]  ...
# 2     56     31      6      4       180.65               []  ...
# 3      6      7      1      0        85.71               []  ...
# 4     30     22      2      1       136.36               []  ...
# 5      0      0      0      0         0.00       [1, 3, 16]  ...
# 6     12     10      1      0       120.00               []  ...
# 7      0      0      0      0         0.00    [4, 7, 9, 11]  ...
# 8      4      3      1      0       133.33               []  ...
# 9      6      9      0      0        66.67               []  ...
# 10     5      6      1      0        83.33      [6, 13, 15]  ...
# 11     1      1      0      0       100.00       [2, 5, 17]  ...
# 12    56     31      9      2       180.65               []  ...
# 13    59     36      4      3       163.89               []  ...
# 14    10     10      1      0       100.00               []  ...
# 15    34     16      5      1       212.50               []  ...
# 16     0      0      0      0         0.00   [7, 9, 12, 16]  ...
# 17    15      5      2      1       300.00         [14, 17]  ...
# 18     0      0      0      0         0.00               []  ...
# 19     0      0      0      0         0.00               []  ...
# 20     0      0      0      0         0.00  [5, 11, 13, 15]  ...
# 21     0      0      0      0         0.00       [4, 8, 10]  ...
# 22     0      0      0      0         0.00   [1, 3, 18, 20]  ...
# 23     0      0      0      0         0.00       [2, 6, 19]  ...
#
#     economy_rate  catches  stumping  direct_hit  indirect_hit  strike_rate_fp  \
# 0           0.00        0         0           0             0               0
# 1           6.75        0         0           0             0               4
# 2           0.00        0         0           0             0               6
# 3           0.00        0         0           0             0               0
# 4           0.00        0         0           0             0               2
# 5          14.00        0         0           0             0               0
# 6           0.00        1         0           0             0               0
# 7          10.75        0         0           0             0               0
# 8           0.00        0         0           0             0               0
# 9           0.00        1         0           0             0               0
# 10         10.67        0         0           0             0               0
# 11         13.29        1         0           0             0               0
# 12          0.00        0         0           0             0               6
# 13          0.00        0         0           0             0               4
# 14          0.00        0         0           0             0               0
# 15          0.00        0         0           0             0               6
# 16         11.75        0         0           0             0               0
# 17          7.00        0         0           0             0               0
# 18          0.00        4         0           0             0               0
# 19          0.00        0         0           0             0               0
# 20          7.25        0         0           0             0               0
# 21         11.67        1         0           0             0               0
# 22          5.50        0         0           0             0               0
# 23          8.33        0         0           0             0               0
#
#     batting_fp  bowling_fp  fielding_fp  total_fp
# 0            8           0            0        12
# 1           90          31            0       125
# 2          118           0            0       122
# 3           10           0            0        14
# 4           50           0            0        54
# 5            0          23            0        27
# 6           16           0            8        28
# 7            0          30            0        34
# 8            8           0            0        12
# 9            6           0            8        18
# 10           9           2            0        15
# 11           1           0            8        13
# 12         118           0            0       122
# 13         105           0            0       109
# 14          14           0            0        18
# 15          70           0            0        74
# 16           0          37            0        41
# 17          29           4            0        37
# 18           0           0           36        40
# 19           0           0            0         4
# 20           0         103            0       107
# 21           0          29            8        41
# 22           0          69            0        73
# 23           0          32            0        36
#
# [24 rows x 32 columns]

# %%
# match01_player = match01_player.join(
#     match01.set_index('name')['total_fp'],
#     on='Player Name'
# )
# match01_player.reset_index()

df = df.join(
    match_1.set_index('name')['total_fp'],
    on = 'Player Name'
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 7
#       1 # match01_player = match01_player.join(
#       2 #     match01.set_index('name')['total_fp'],
#       3 #     on='Player Name'
#       4 # )
#       5 # match01_player.reset_index()
# ----> 7 df = df.join(
#       8     match_1.set_index('name')['total_fp'],
#       9     on = 'Player Name'
#      10 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:10757, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10747     if how == "cross":
#   10748         return merge(
#   10749             self,
#   10750             other,
#    (...)
#   10755             validate=validate,
#   10756         )
# > 10757     return merge(
#   10758         self,
#   10759         other,
#   10760         left_on=on,
#   10761         how=how,
#   10762         left_index=on is None,
#   10763         right_index=True,
#   10764         suffixes=(lsuffix, rsuffix),
#   10765         sort=sort,
#   10766         validate=validate,
#   10767     )
#   10768 else:
#   10769     if on is not None:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\reshape\merge.py:840, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     837 left = self.left[:]
#     838 right = self.right[:]
# --> 840 llabels, rlabels = _items_overlap_with_suffix(
#     841     self.left._info_axis, self.right._info_axis, self.suffixes
#     842 )
#     844 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     845     # Pinning the index here (and in the right code just below) is not
#     846     #  necessary, but makes the `.take` more performant if we have e.g.
#     847     #  a MultiIndex for left.index.
#     848     lmgr = left._mgr.reindex_indexer(
#     849         join_index,
#     850         left_indexer,
#    (...)
#     855         use_na_proxy=True,
#     856     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\reshape\merge.py:2721, in _items_overlap_with_suffix(left, right, suffixes)
#    2718 lsuffix, rsuffix = suffixes
#    2720 if not lsuffix and not rsuffix:
# -> 2721     raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2723 def renamer(x, suffix: str | None):
#    2724     """
#    2725     Rename the left and right indices.
#    2726
#    (...)
#    2737     x : renamed column name
#    2738     """
#
# ValueError: columns overlap but no suffix specified: Index(['total_fp'], dtype='object')

# %%
# df = df.reset_index()

# %%
df
# Out:
#     index  Credits Player Type      Player Name                         Team  \
# 0      15      8.0          WK        Q de Kock        Kolkata Knight Riders
# 1      25      8.0         BAT          VR Iyer        Kolkata Knight Riders
# 2      27      7.5         BAT        AM Rahane        Kolkata Knight Riders
# 3      24      7.5         BAT         RK Singh        Kolkata Knight Riders
# 4      22      6.5         BAT    A Raghuvanshi        Kolkata Knight Riders
# 5      10      9.0         ALL        SP Narine        Kolkata Knight Riders
# 6       9      8.5         ALL       AD Russell        Kolkata Knight Riders
# 7       7      7.5         ALL  Ramandeep Singh        Kolkata Knight Riders
# 8      40      6.5        BOWL       SH Johnson        Kolkata Knight Riders
# 9      36      8.0        BOWL     Harshit Rana        Kolkata Knight Riders
# 10     41      9.0        BOWL         CV Varun        Kolkata Knight Riders
# 11     42      8.0        BOWL              NaN        Kolkata Knight Riders
# 12     26      7.0         BAT              NaN        Kolkata Knight Riders
# 13     38      6.5        BOWL         VG Arora        Kolkata Knight Riders
# 14      6      6.0         ALL              NaN        Kolkata Knight Riders
# 15     13      5.5          WK              NaN        Kolkata Knight Riders
# 16     21      9.0         BAT          V Kohli  Royal Challengers Bengaluru
# 17     12      8.5          WK          PD Salt  Royal Challengers Bengaluru
# 18     20      8.0         BAT       RM Patidar  Royal Challengers Bengaluru
# 19      4      8.0         ALL   LS Livingstone  Royal Challengers Bengaluru
# 20     11      7.5          WK        JM Sharma  Royal Challengers Bengaluru
# 21     18      7.5         BAT         TH David  Royal Challengers Bengaluru
# 22      3      7.5         ALL        KH Pandya  Royal Challengers Bengaluru
# 23     30      6.5        BOWL     Rasikh Salam  Royal Challengers Bengaluru
# 24     29      6.0        BOWL    Suyash Sharma  Royal Challengers Bengaluru
# 25     34      8.5        BOWL     JR Hazlewood  Royal Challengers Bengaluru
# 26     31      7.0        BOWL       Yash Dayal  Royal Challengers Bengaluru
# 27     19      7.0         BAT       D Padikkal  Royal Challengers Bengaluru
# 28     28      5.0        BOWL              NaN  Royal Challengers Bengaluru
# 29      1      6.5         ALL              NaN  Royal Challengers Bengaluru
# 30      2      7.0         ALL              NaN  Royal Challengers Bengaluru
# 31      5      7.0         ALL              NaN  Royal Challengers Bengaluru
#
#               IsPlaying  lineupOrder  total_fp
# 0               PLAYING            1      12.0
# 1               PLAYING            2      14.0
# 2               PLAYING            3     122.0
# 3               PLAYING            4      28.0
# 4               PLAYING            5      54.0
# 5               PLAYING            6     125.0
# 6               PLAYING            7      12.0
# 7               PLAYING            8      18.0
# 8               PLAYING            9      13.0
# 9               PLAYING           10      15.0
# 10              PLAYING           11      34.0
# 11  X_FACTOR_SUBSTITUTE           12       NaN
# 12  X_FACTOR_SUBSTITUTE           13       NaN
# 13  X_FACTOR_SUBSTITUTE           14      27.0
# 14  X_FACTOR_SUBSTITUTE           15       NaN
# 15  X_FACTOR_SUBSTITUTE           16       NaN
# 16              PLAYING            1     109.0
# 17              PLAYING            2     122.0
# 18              PLAYING            3      74.0
# 19              PLAYING            4      37.0
# 20              PLAYING            5      40.0
# 21              PLAYING            6       4.0
# 22              PLAYING            7     107.0
# 23              PLAYING            8      41.0
# 24              PLAYING            9      41.0
# 25              PLAYING           10      73.0
# 26              PLAYING           11      36.0
# 27  X_FACTOR_SUBSTITUTE           12      18.0
# 28  X_FACTOR_SUBSTITUTE           13       NaN
# 29  X_FACTOR_SUBSTITUTE           14       NaN
# 30  X_FACTOR_SUBSTITUTE           15       NaN
# 31  X_FACTOR_SUBSTITUTE           16       NaN

# %%
df.dropna(inplace=True)
df
# Out:
#     index  Credits Player Type      Player Name                         Team  \
# 0      15      8.0          WK        Q de Kock        Kolkata Knight Riders
# 1      25      8.0         BAT          VR Iyer        Kolkata Knight Riders
# 2      27      7.5         BAT        AM Rahane        Kolkata Knight Riders
# 3      24      7.5         BAT         RK Singh        Kolkata Knight Riders
# 4      22      6.5         BAT    A Raghuvanshi        Kolkata Knight Riders
# 5      10      9.0         ALL        SP Narine        Kolkata Knight Riders
# 6       9      8.5         ALL       AD Russell        Kolkata Knight Riders
# 7       7      7.5         ALL  Ramandeep Singh        Kolkata Knight Riders
# 8      40      6.5        BOWL       SH Johnson        Kolkata Knight Riders
# 9      36      8.0        BOWL     Harshit Rana        Kolkata Knight Riders
# 10     41      9.0        BOWL         CV Varun        Kolkata Knight Riders
# 13     38      6.5        BOWL         VG Arora        Kolkata Knight Riders
# 16     21      9.0         BAT          V Kohli  Royal Challengers Bengaluru
# 17     12      8.5          WK          PD Salt  Royal Challengers Bengaluru
# 18     20      8.0         BAT       RM Patidar  Royal Challengers Bengaluru
# 19      4      8.0         ALL   LS Livingstone  Royal Challengers Bengaluru
# 20     11      7.5          WK        JM Sharma  Royal Challengers Bengaluru
# 21     18      7.5         BAT         TH David  Royal Challengers Bengaluru
# 22      3      7.5         ALL        KH Pandya  Royal Challengers Bengaluru
# 23     30      6.5        BOWL     Rasikh Salam  Royal Challengers Bengaluru
# 24     29      6.0        BOWL    Suyash Sharma  Royal Challengers Bengaluru
# 25     34      8.5        BOWL     JR Hazlewood  Royal Challengers Bengaluru
# 26     31      7.0        BOWL       Yash Dayal  Royal Challengers Bengaluru
# 27     19      7.0         BAT       D Padikkal  Royal Challengers Bengaluru
#
#               IsPlaying  lineupOrder  total_fp
# 0               PLAYING            1      12.0
# 1               PLAYING            2      14.0
# 2               PLAYING            3     122.0
# 3               PLAYING            4      28.0
# 4               PLAYING            5      54.0
# 5               PLAYING            6     125.0
# 6               PLAYING            7      12.0
# 7               PLAYING            8      18.0
# 8               PLAYING            9      13.0
# 9               PLAYING           10      15.0
# 10              PLAYING           11      34.0
# 13  X_FACTOR_SUBSTITUTE           14      27.0
# 16              PLAYING            1     109.0
# 17              PLAYING            2     122.0
# 18              PLAYING            3      74.0
# 19              PLAYING            4      37.0
# 20              PLAYING            5      40.0
# 21              PLAYING            6       4.0
# 22              PLAYING            7     107.0
# 23              PLAYING            8      41.0
# 24              PLAYING            9      41.0
# 25              PLAYING           10      73.0
# 26              PLAYING           11      36.0
# 27  X_FACTOR_SUBSTITUTE           12      18.0

# %%
def PredictTeam(df: pd.DataFrame):
    """ 
    The optimization maximizes the total fanstasy points while satisfying the following Contraints:-
    -Exactly 11 pplayers are selected.
    -The total credits of selected players does not exceed 100
    -For each player type (role) the selection is between the specified minimum and maximum limits.
    -No more than the maximum allowed players are selected from any single real-life team.
    
    :params df: processed DataFrame containing Players details including expected fanstasy score
    : return : list of ids of 11 players (maybe including their names.)
    """
    #Dream 11 constraints 
    Total_Players = 11
    MAX_TOTAL_CREDITS = 100
    MIN_PER_ROLE = 1
    MAX_PER_ROLE = 4
    MAX_PER_TEAM = 7  # Adjust this based on your requirements
    roles = ['BAT','BOWL','WK','ALL']
    prob = pulp.LpProblem(name='OPtimal_Team',sense=pulp.LpMaximize)
    decision_var = {i : pulp.LpVariable(f'x_{i}',cat='Binary') for i in df.index}
    prob += pulp.lpSum(df.loc[i,'total_fp']* decision_var[i] for i in df.index), 'TotalFantasyPoints'
    prob += pulp.lpSum(decision_var[i] for i in df.index) == Total_Players, 'TotalPlayers'
    prob += pulp.lpSum(df.loc[i,'Credits']*decision_var[i] for i in df.index) <= MAX_TOTAL_CREDITS ,'CreditLimit'
    for role in roles:
        role_indices = df.index[df['Player Type'] == role].tolist()
        if role_indices:
            prob += pulp.lpSum(decision_var[i] for i in role_indices) >= MIN_PER_ROLE, f'MIN_{role}'
            prob += pulp.lpSum(decision_var[i] for i in role_indices) <= MAX_PER_ROLE, f'MAX_{role}'
    for team in df['Team'].unique():
        team_indices = df.index[df['Team'] == team].tolist()
        prob += pulp.lpSum(decision_var[i] for i in team_indices) <= MAX_PER_TEAM, f'TeamLimt_{team}'
    
    #solve the optimization problem 
    solution_status = prob.solve()
    # print(prob)
    print("Optimization Status:", pulp.LpStatus[solution_status])
    selected_indices = [i for i in df.index if pulp.value(decision_var[i] == 1)]
    selected_team_df = df.loc[selected_indices]
    return selected_team_df

# %%
optimal_team_df = PredictTeam(df)
optimal_team_df.sort_values(by=['total_fp'],ascending= False)
# print("\nSelected Dream11 Team:")
# print(optimal_team_df[['Player Name', 'Player Type', 'Credits', 'Team', 'total_fp', 'lineupOrder']])
total_fp_selected = optimal_team_df['total_fp'].sum()
total_credits_selected = optimal_team_df['Credits'].sum()
print(f"\nTotal Fantasy Points: {total_fp_selected}")
print(f"Total Credits Used: {total_credits_selected}")
# Out:
# Optimization Status: Optimal
#
# Total Fantasy Points: 274.0
# Total Credits Used: 97.5

# %%
optimal_team_df
# Out:
#     index  Credits Player Type      Player Name                         Team  \
# 0      15      8.0          WK        Q de Kock        Kolkata Knight Riders
# 1      25      8.0         BAT          VR Iyer        Kolkata Knight Riders
# 3      24      7.5         BAT         RK Singh        Kolkata Knight Riders
# 6       9      8.5         ALL       AD Russell        Kolkata Knight Riders
# 7       7      7.5         ALL  Ramandeep Singh        Kolkata Knight Riders
# 8      40      6.5        BOWL       SH Johnson        Kolkata Knight Riders
# 9      36      8.0        BOWL     Harshit Rana        Kolkata Knight Riders
# 13     38      6.5        BOWL         VG Arora        Kolkata Knight Riders
# 19      4      8.0         ALL   LS Livingstone  Royal Challengers Bengaluru
# 20     11      7.5          WK        JM Sharma  Royal Challengers Bengaluru
# 21     18      7.5         BAT         TH David  Royal Challengers Bengaluru
# 26     31      7.0        BOWL       Yash Dayal  Royal Challengers Bengaluru
# 27     19      7.0         BAT       D Padikkal  Royal Challengers Bengaluru
#
#               IsPlaying  lineupOrder  total_fp
# 0               PLAYING            1      12.0
# 1               PLAYING            2      14.0
# 3               PLAYING            4      28.0
# 6               PLAYING            7      12.0
# 7               PLAYING            8      18.0
# 8               PLAYING            9      13.0
# 9               PLAYING           10      15.0
# 13  X_FACTOR_SUBSTITUTE           14      27.0
# 19              PLAYING            4      37.0
# 20              PLAYING            5      40.0
# 21              PLAYING            6       4.0
# 26              PLAYING           11      36.0
# 27  X_FACTOR_SUBSTITUTE           12      18.0

# %%
optimal_team = PredictTeam(df)
# Out:
# OPtimal_Team:
# MAXIMIZE
# 12.0*x_0 + 14.0*x_1 + 34.0*x_10 + 27.0*x_13 + 109.0*x_16 + 122.0*x_17 + 74.0*x_18 + 37.0*x_19 + 122.0*x_2 + 40.0*x_20 + 4.0*x_21 + 107.0*x_22 + 41.0*x_23 + 41.0*x_24 + 73.0*x_25 + 36.0*x_26 + 18.0*x_27 + 28.0*x_3 + 54.0*x_4 + 125.0*x_5 + 12.0*x_6 + 18.0*x_7 + 13.0*x_8 + 15.0*x_9 + 0.0
# SUBJECT TO
# TotalPlayers: x_0 + x_1 + x_10 + x_13 + x_16 + x_17 + x_18 + x_19 + x_2 + x_20
#  + x_21 + x_22 + x_23 + x_24 + x_25 + x_26 + x_27 + x_3 + x_4 + x_5 + x_6
#  + x_7 + x_8 + x_9 = 11
#
# CreditLimit: 8 x_0 + 8 x_1 + 9 x_10 + 6.5 x_13 + 9 x_16 + 8.5 x_17 + 8 x_18
#  + 8 x_19 + 7.5 x_2 + 7.5 x_20 + 7.5 x_21 + 7.5 x_22 + 6.5 x_23 + 6 x_24
#  + 8.5 x_25 + 7 x_26 + 7 x_27 + 7.5 x_3 + 6.5 x_4 + 9 x_5 + 8.5 x_6 + 7.5 x_7
#  + 6.5 x_8 + 8 x_9 <= 100
#
# MIN_BAT: x_1 + x_16 + x_18 + x_2 + x_21 + x_27 + x_3 + x_4 >= 1
#
# MAX_BAT: x_1 + x_16 + x_18 + x_2 + x_21 + x_27 + x_3 + x_4 <= 4
#
# MIN_BOWL: x_10 + x_13 + x_23 + x_24 + x_25 + x_26 + x_8 + x_9 >= 1
#
# MAX_BOWL: x_10 + x_13 + x_23 + x_24 + x_25 + x_26 + x_8 + x_9 <= 4
#
# MIN_WK: x_0 + x_17 + x_20 >= 1
#
# MAX_WK: x_0 + x_17 + x_20 <= 4
#
# MIN_ALL: x_19 + x_22 + x_5 + x_6 + x_7 >= 1
#
# MAX_ALL: x_19 + x_22 + x_5 + x_6 + x_7 <= 4
#
# TeamLimt_Kolkata_Knight_Riders: x_0 + x_1 + x_10 + x_13 + x_2 + x_3 + x_4
#  + x_5 + x_6 + x_7 + x_8 + x_9 <= 7
#
# TeamLimt_Royal_Challengers_Bengaluru: x_16 + x_17 + x_18 + x_19 + x_20 + x_21
#  + x_22 + x_23 + x_24 + x_25 + x_26 + x_27 <= 7
#
# VARIABLES
# 0 <= x_0 <= 1 Integer
# 0 <= x_1 <= 1 Integer
# 0 <= x_10 <= 1 Integer
# 0 <= x_13 <= 1 Integer
# 0 <= x_16 <= 1 Integer
# 0 <= x_17 <= 1 Integer
# 0 <= x_18 <= 1 Integer
# 0 <= x_19 <= 1 Integer
# 0 <= x_2 <= 1 Integer
# 0 <= x_20 <= 1 Integer
# 0 <= x_21 <= 1 Integer
# 0 <= x_22 <= 1 Integer
# 0 <= x_23 <= 1 Integer
# 0 <= x_24 <= 1 Integer
# 0 <= x_25 <= 1 Integer
# 0 <= x_26 <= 1 Integer
# 0 <= x_27 <= 1 Integer
# 0 <= x_3 <= 1 Integer
# 0 <= x_4 <= 1 Integer
# 0 <= x_5 <= 1 Integer
# 0 <= x_6 <= 1 Integer
# 0 <= x_7 <= 1 Integer
# 0 <= x_8 <= 1 Integer
# 0 <= x_9 <= 1 Integer
#
# Optimization Status: Optimal

# %%
optimal_team
# Out:
#     index  Credits Player Type      Player Name                         Team  \
# 0      15      8.0          WK        Q de Kock        Kolkata Knight Riders
# 1      25      8.0         BAT          VR Iyer        Kolkata Knight Riders
# 3      24      7.5         BAT         RK Singh        Kolkata Knight Riders
# 6       9      8.5         ALL       AD Russell        Kolkata Knight Riders
# 7       7      7.5         ALL  Ramandeep Singh        Kolkata Knight Riders
# 8      40      6.5        BOWL       SH Johnson        Kolkata Knight Riders
# 9      36      8.0        BOWL     Harshit Rana        Kolkata Knight Riders
# 13     38      6.5        BOWL         VG Arora        Kolkata Knight Riders
# 19      4      8.0         ALL   LS Livingstone  Royal Challengers Bengaluru
# 20     11      7.5          WK        JM Sharma  Royal Challengers Bengaluru
# 21     18      7.5         BAT         TH David  Royal Challengers Bengaluru
# 26     31      7.0        BOWL       Yash Dayal  Royal Challengers Bengaluru
# 27     19      7.0         BAT       D Padikkal  Royal Challengers Bengaluru
#
#               IsPlaying  lineupOrder  total_fp
# 0               PLAYING            1      12.0
# 1               PLAYING            2      14.0
# 3               PLAYING            4      28.0
# 6               PLAYING            7      12.0
# 7               PLAYING            8      18.0
# 8               PLAYING            9      13.0
# 9               PLAYING           10      15.0
# 13  X_FACTOR_SUBSTITUTE           14      27.0
# 19              PLAYING            4      37.0
# 20              PLAYING            5      40.0
# 21              PLAYING            6       4.0
# 26              PLAYING           11      36.0
# 27  X_FACTOR_SUBSTITUTE           12      18.0
